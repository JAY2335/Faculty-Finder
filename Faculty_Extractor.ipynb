# %%
import pandas as pd

# %%
dataset=pd.read_csv('FallSemester2020-21CourseAllocation1 (1).csv')

# %%
dataset
# Out:
#      courseowner    ccode  ... totalseats Unnamed: 16
# 0           ACAD  MGT1022  ...         70         NaN
# 1           ACAD  MGT1022  ...         70         NaN
# 2           ACAD  MGT1022  ...         70         NaN
# 3           ACAD  MGT1022  ...         70         NaN
# 4           ACAD  MGT1022  ...         70         NaN
# ...          ...      ...  ...        ...         ...
# 3844      VSPARC  ARC5015  ...         15         NaN
# 3845      VSPARC  ARC5015  ...         15         NaN
# 3846      VSPARC  ARC5015  ...         15         NaN
# 3847      VSPARC  ARC5015  ...         15         NaN
# 3848      VSPARC  ARC5015  ...         15         NaN
#
# [3849 rows x 17 columns]

# %%
faculties=list(dataset[dataset['ccode']==f'{text}']['ename'].unique())
faculties
df=pd.DataFrame(faculties)
df.to_csv(f"{}.csv")
# Out:
# ['SRI ADIBHATLA SRIDEVI',
#  'RAVI S',
#  'ANITHA',
#  'RAGUNATH G',
#  'SATHEESH KUMAR S',
#  'PRAYLINE RAJABAI C']

# %%
df=pd.DataFrame(faculties)
df.to_csv("Digital Logic Design.csv")

# %%
slots=dataset[dataset['ccode']=='MAT2002']['slot']
slots
# Out:
# 385     F1+TF1
# 386     G2+TG2
# 387     D1+TD1
# 388     G1+TG1
# 389     G2+TG2
# 390     D2+TD2
# 391     B1+TB1
# 392     B2+TB2
# 393     G1+TG1
# 394     G2+TG2
# 395     B1+TB1
# 396     B2+TB2
# 397     D1+TD1
# 398     D2+TD2
# 399     F1+TF1
# 400     F2+TF2
# 401     G1+TG1
# 402     G2+TG2
# 403     F1+TF1
# 404     F2+TF2
# 405     G1+TG1
# 406     B1+TB1
# 407     B2+TB2
# 408      L1+L2
# 409      L7+L8
# 410     L9+L10
# 411    L21+L22
# 412    L33+L34
# 413    L39+L40
# 414    L49+L50
# 415    L59+L60
# 416    L19+L20
# 417    L45+L46
# 418    L11+L12
# 419    L15+L16
# 420      L5+L6
# 421    L37+L38
# 422    L57+L58
# 423      L3+L4
# 424    L39+L40
# 425    L47+L48
# 426    L59+L60
# 427    L29+L30
# 428    L33+L34
# 429    L31+L32
# 430    L23+L24
# 431     F1+TF1
# 432     F2+TF2
# 433    L51+L52
# 434     L9+L10
# 435     D1+TD1
# 436    L53+L54
# Name: slot, dtype: object
